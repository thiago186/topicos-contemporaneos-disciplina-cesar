# %% [markdown]
# # RAG - Retrieval Augmented Generation
# Trabalho final da disciplina de Topicos Contemporaneos
#
# Alunos:
# - Thiago Amorim: twa@cesar.school
# - Arthur Wanderley:

# %% [markdown]
# # Criação do vector store
#
# Como o objetivo do trabalho é criar um sistema de RAG, escolhemos popular o vector store com informações fictícias, visto que o LLM não conseguiria utilizar seu conhecimento para responder as perguntas, e só conseguiria responder extraindo as informações do vector store.
#
# Para isso, usamos o Claude 3.5 Sonnet para criar um conjunto de documentos fictícios sobre um robô biomimético para a exploração submarina.
# Os documentos gerados estão na pasta `data/documents`. Eles serão separados para a população do vector store.
#
# Analisando os documentos gerados, podemos perceber que eles possuem uma estrutura bem definida em `markdown`, e que cada seção não possui um tamanho muito grande, o que facilita a extração de informações, já que não excede a janela de contexto do LLM.
#
# Por isso, optamos por criar cada documento separando a partir da seção de título do markdown (#).
# Cada documento criado incluirá as subseções do documento original, e o título do documento será o título do documento original.

# %%
# !pip install langchain
# !pip install openai
# Out:
# Requirement already satisfied: langchain in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (0.3.13)
# Requirement already satisfied: PyYAML>=5.3 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain) (3.11.10)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.26 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain) (0.3.28)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain) (0.3.4)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain) (0.2.6)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.26->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.26->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.26->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.17->langchain) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: anyio in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: sniffio in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.26->langchain) (3.0.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: openai in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (1.53.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai) (0.6.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os

from langchain_core.documents import Document


def parse_document(content: str) -> list[Document]:
    """Cria documentos a partir do conteúdo de um arquivo.
    
    Exemplo:
    ```
    # Título do documento
    ## Seção 1
    Todo o texto vai para o documento 1
    ### Subseção 1.1
    Todo o texto vai para o documento 1
    ### Subseção 1.2
    Todo o texto vai para o documento 1
    ## Seção 2
    Todo o texto vai para o documento 2
    ### Subseção 2.1
    Todo o texto vai para o documento 2
    ```
    resultado:
    [
        Document(page_content='## Seção 1\nTodo o texto vai para o documento 1\n### Subseção 1.1\nTodo o texto vai para o documento 1\n### Subseção 1.2\nTodo o texto vai para o documento 1', metadata={'source': 'Título do documento'}),
        Document(page_content='## Seção 2\nTodo o texto vai para o documento 2\n### Subseção 2.1\nTodo o texto vai para o documento 2', metadata={'source': 'Título do documento'})
    ]
    """
    documents = []
    current_title = None
    current_content = ""

    for line in content.split('\n'):
        if line.startswith('## '):
            if current_title:
                documents.append(Document(page_content= "## " + current_title + '\n' + current_content, metadata={'source': current_title}))
                current_content = ""
            current_title = line[2:].strip()
        else:
            current_content += line + '\n'
    
    if current_title:
        documents.append(Document(page_content=current_content, metadata={'source': current_title}))
    
    return documents
    

#list all files in documents/
files = os.listdir('./documents/')

#load each file
documents = []
for file in files:
    with open(f'./documents/{file}', 'r') as f:
        documents.extend(parse_document(f.read()))

# %%
documents
# Out:
# [Document(metadata={'source': 'Projeto HidroNáutica X-700'}, page_content='## Projeto HidroNáutica X-700\n# Relatório Técnico Confidencial\n### Divisão de Robótica Submarina Avançada\n#### NeuroTech Oceanic Solutions\n**Versão do Documento: 1.4**\n**Data de Última Atualização: 15 de dezembro de 2037**\n\n'),
#  Document(metadata={'source': '1. Introdução ao Projeto'}, page_content='## 1. Introdução ao Projeto\n\nO robô biomimético HidroNáutica X-700 representa um avanço revolucionário na exploração de ambientes submarinos extremos. Desenvolvido através de uma parceria interdisciplinar entre a NeuroTech Oceanic Solutions e o Instituto de Robótica Biomimética da Universidade Federal Marítima, o projeto visa criar um dispositivo de exploração que supere as limitações dos sistemas robóticos tradicionais.\n\n'),
#  Document(metadata={'source': '2. Concepção Biomimética'}, page_content='## 2. Concepção Biomimética\n\nA inspiração principal para o X-700 veio do estudo detalhado de duas espécies marinhas de movimentação excepcional:\n- Enguia elétrica do Rio Amazonas (Electrophorus electricus)\n- Lula gigante de profundidade (Architeuthis dux)\n\n### 2.1 Princípios de Biomimetismo\n\nO robô incorpora três princípios fundamentais de biomimetismo:\n\n1. **Propulsão Ondulante**: Sistema de locomoção que replica o movimento serpentino das enguias, permitindo movimentação precisa em diferentes densidades de água.\n\n2. **Sistema de Camuflagem Dinâmica**: Inspirado na capacidade das lulas de alterar instantaneamente sua pigmentação e textura, o X-700 possui uma camada externa de nanomateriais que podem modificar sua aparência e propriedades térmicas.\n\n3. **Sistema Sensorial Adaptativo**: Rede de sensores distribuídos que mimetizam o sistema nervoso de criaturas marinhas, permitindo resposta quase instantânea a mudanças no ambiente.\n\n'),
#  Document(metadata={'source': '3. Especificações Técnicas'}, page_content='## 3. Especificações Técnicas\n\n### 3.1 Dimensões e Peso\n- Comprimento: 2,7 metros\n- Largura máxima: 0,65 metros\n- Peso: 278 kg (em configuração padrão)\n- Peso em ambiente submarino: Aproximadamente 42 kg devido à flutuabilidade assistida\n\n### 3.2 Materiais Estruturais\n- Casco externo: Liga de titânio-grafeno desenvolvida exclusivamente pela NeuroTech\n- Revestimento interno: Polímero biocerâmico resistente a alta pressão\n- Juntas de movimentação: Compósito de nanotubos de carbono com memória de forma\n\n'),
#  Document(metadata={'source': '4. Sistemas de Propulsão'}, page_content='## 4. Sistemas de Propulsão\n\n### 4.1 Módulo de Propulsão Principal\nO sistema de propulsão do X-700 utiliza um mecanismo de ondulação muscular artificial, composto por:\n- 17 atuadores piezoelétricos de alta precisão\n- Sistema hidráulico de baixa fricção\n- Controlador neural de movimento com 342 pontos de ajuste micrometálicos\n\n### 4.2 Eficiência Energética\n- Fonte de energia: Bateria de estado sólido com nanocristais de sulfeto\n- Autonomia: 72 horas em modo de exploração ativa\n- Capacidade de recarga: Conversão termoelétrica de gradientes de temperatura submarina\n\n'),
#  Document(metadata={'source': '5. Sistemas Sensoriais'}, page_content='## 5. Sistemas Sensoriais\n\n### 5.1 Arquitetura Sensorial\nO X-700 possui um conjunto único de sensores:\n- 6 câmeras hiperespectrais com resolução de 0,03 milímetros\n- Sensor biomagnético de 12 canais\n- Sistema LIDAR de varredura quântica\n- Sensores químicos de análise molecular em tempo real\n\n### 5.2 Processamento de Dados\n- Unidade de processamento neural: Chip quântico de 1024 qubits\n- Algoritmo de aprendizado adaptativo baseado em redes neurais biomorfas\n- Capacidade de processamento: 742 petaFLOPS\n\n'),
#  Document(metadata={'source': '6. Desafios de Desenvolvimento'}, page_content='## 6. Desafios de Desenvolvimento\n\nDurante o desenvolvimento do X-700, a equipe enfrentou diversos desafios técnicos:\n\n1. **Problema de Ressonância Biomecânica**: Superado através da implementação de um sistema de amortecimento nano-viscoso.\n\n2. **Limitações de Comunicação em Profundidade**: Desenvolvido um protocolo de comunicação acústica de ultra-baixa frequência, permitindo transmissão de dados em profundidades superiores a 7.000 metros.\n\n3. **Estabilidade Térmica**: Criação de um sistema de regulação térmica inspirado no mecanismo de contracorrente encontrado em algumas espécies de atuns.\n\n'),
#  Document(metadata={'source': '7. Aplicações Potenciais'}, page_content='## 7. Aplicações Potenciais\n\nO HidroNáutica X-700 foi projetado para:\n- Mapeamento de ecossistemas marinhos profundos\n- Investigação geológica submarina\n- Pesquisa de biodiversidade em zonas hadais\n- Missões de recuperação e inspeção de estruturas submarinas\n\n'),
#  Document(metadata={'source': '8. Limitações Conhecidas'}, page_content='## 8. Limitações Conhecidas\n\nApesar de seus avanços, o robô apresenta algumas limitações:\n- Vulnerabilidade a campos eletromagnéticos intensos\n- Tempo limitado de operação em zonas de temperatura extremamente baixa\n- Dependência de calibração periódica dos sistemas neurais\n\n'),
#  Document(metadata={'source': '9. Conclusão'}, page_content='## 9. Conclusão\n\nO HidroNáutica X-700 representa mais do que um robô submarino - é um marco na integração entre biologia, robótica e inteligência artificial. Suas capacidades únicas abrem novos horizontes para a exploração dos ambientes marinhos mais desafiadores do nosso planeta.\n\n\n'),
#  Document(metadata={'source': '10. Equipe de Desenvolvimento'}, page_content='\n### 10.1 Liderança do Projeto\n\n#### Dra. Elena Rodrigues Silva\n**Cargo:** Diretora de Pesquisa e Coordenadora Geral do Projeto\n**Contribuições Principais:** \n- Concepção inicial do conceito biomimético\n- Definição da arquitetura geral do robô\n- Supervisão estratégica do desenvolvimento\n\n**Currículo Resumido:**\n- Doutorado em Robótica Biomimética pela Universidade de Stanford\n- Mais de 15 anos de experiência em desenvolvimento de robôs autônomos\n- Autora de 87 publicações científicas em robótica marinha\n- Membro da Academia Nacional de Engenharia desde 2033\n\n#### Dr. Marcus Chen Wong\n**Cargo:** Diretor Técnico de Engenharia\n**Contribuições Principais:**\n- Desenvolvimento do sistema de propulsão ondulante\n- Design dos atuadores piezoelétricos\n- Modelagem computacional dos sistemas de movimento\n\n**Currículo Resumido:**\n- PhD em Engenharia Biomecânica pelo MIT\n- Especialista mundial\n'),
#  Document(metadata={'source': 'Projeto HidroNáutica X-700'}, page_content='## Projeto HidroNáutica X-700\n# Relatório Confidencial de Missão\n### Primeira Missão de Teste em Ambiente Extremo\n**Código da Missão:** NMEX-2038-001\n**Data da Missão:** 17 a 24 de março de 2038\n**Local:** Fossa das Marianas, Oceano Pacífico\n\n'),
#  Document(metadata={'source': '1. Sumário Executivo'}, page_content='## 1. Sumário Executivo\n\nA primeira missão de teste do robô HidroNáutica X-700 foi realizada na região mais profunda dos oceanos terrestres - a Fossa das Marianas. O objetivo principal era avaliar o desempenho do dispositivo em condições de pressão extrema, testar sistemas de navegação autônoma e coletar dados geológicos e biológicos inéditos.\n\n'),
#  Document(metadata={'source': '2. Parâmetros da Missão'}, page_content='## 2. Parâmetros da Missão\n\n### 2.1 Objetivos Específicos\n1. Sobrevivência e operação em profundidade superior a 10.000 metros\n2. Coleta de amostras geológicas e biológicas\n3. Mapeamento topográfico de área não documentada\n4. Teste de sistemas de comunicação e navegação\n\n### 2.2 Configuração Inicial\n- Profundidade máxima planejada: 10.911 metros\n- Duração prevista: 72 horas\n- Autonomia de energia: 100% da capacidade\n- Modo de operação: Exploração autônoma com controle remoto ocasional\n\n'),
#  Document(metadata={'source': '3. Sequência de Eventos'}, page_content='## 3. Sequência de Eventos\n\n### Dia 1 (17/03/2038)\n**07:45 - Lançamento**\n- Ponto de partida: Navio de pesquisa NeuroTech Ocean Explorer\n- Coordenadas: 11°22\'13"N, 142°35\'29"E\n- Condições meteorológicas: Mar calmo, visibilidade excelente\n\n**09:12 - Primeiro Mergulho**\n- Profundidade inicial: 1.200 metros\n- Primeiros testes de propulsão ondulante\n- Sistema de camuflagem dinâmica demonstra eficiência de 94%\n\n### Dia 2 (18/03/2038)\n**Evento Crítico: Encontro com Estrutura Geológica Desconhecida**\n- Às 14:37, o X-700 detecta formação geológica não mapeada\n- Estrutura semelhante a chaminés hidrotermais, mas com composição mineral inédita\n- Coleta automática de 3 amostras de rocha\n\n### Dia 3 (19/03/2038)\n**Desafio de Comunicação**\n- Perda temporária de sinal entre 06:45 e 07:22\n- Sistema de comunicação acústica de backup ativado com sucesso\n- Nenhuma perda de dados ou comprometimento de missão\n\n### Dia 4 (20/03/2038)\n**Descoberta Biológica**\n- Registro de organismo microbiológico desconhecido\n- Características únicas de sobrevivência em pressão extrema\n- Coleta de amostra biológica para análise posterior\n\n### Dia 5 (21/03/2038)\n**Teste Limite de Pressão**\n- Profundidade máxima alcançada: 10.984 metros\n- Todos os sistemas operando em 98% de eficiência\n- Nenhum dano estrutural observado\n\n### Dia 6 (22/03/2038)\n**Início da Fase de Retorno**\n- Ativação de protocolo de ascensão controlada\n- Coleta de dados oceanográficos durante subida\n- Teste de sistemas de flutuabilidade\n\n### Dia 7 (23/03/2038)\n**Resgate e Recuperação**\n- Retorno ao navio de pesquisa\n- Checagem inicial de sistemas\n- Transferência de dados coletados\n\n'),
#  Document(metadata={'source': '4. Análise de Desempenho'}, page_content='## 4. Análise de Desempenho\n\n### 4.1 Sistemas de Propulsão\n- Eficiência de movimento: 96%\n- Consumo de energia abaixo do previsto em 12%\n- Nenhuma falha nos atuadores piezoelétricos\n\n### 4.2 Sistemas Sensoriais\n- Resolução das câmeras hiperespectrais: 99,7%\n- Sensor biomagnético: Captura de 276 leituras únicas\n- Sistema LIDAR: Mapeamento de área de 42 km²\n\n### 4.3 Desafios e Limitações\n1. Interferência ocasional em comunicações de ultra-baixa frequência\n2. Desgaste parcial no revestimento de nanomateriais\n3. Necessidade de calibração fina dos sensores químicos\n\n'),
#  Document(metadata={'source': '5. Descobertas Científicas'}, page_content='## 5. Descobertas Científicas\n\n- Identificação de nova formação geológica submarina\n- Registro de micro-organismo com características de adaptação extrema\n- Mapeamento detalhado de 67 km² de fundo oceânico não documentado\n\n'),
#  Document(metadata={'source': '6. Conclusão'}, page_content='\nA missão NMEX-2038-001 comprovou as principais capacidades do HidroNáutica X-700. O robô não apenas sobreviveu, mas excedeu expectativas em todos os parâmetros críticos de operação.\n\n**Classificação do Relatório:** CONFIDENCIAL\n**Próximos Passos:** Análise detalhada dos dados coletados e preparação para próxima missão de teste.\n\n*Fim do Relatório*\n\n')]

# %%
# !pip install faiss-cpu
# !pip install python-dotenv
# !pip install langchain-community
# !pip install langchain-openai
# Out:
# Requirement already satisfied: faiss-cpu in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (1.9.0.post1)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from faiss-cpu) (24.1)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: python-dotenv in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (1.0.1)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: langchain-community in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (0.3.14)
# Requirement already satisfied: PyYAML>=5.3 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-community) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-community) (3.11.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.14 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-community) (0.3.14)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.29 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-community) (0.3.29)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-community) (0.2.6)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-community) (2.6.0)
# Requirement already satisfied: requests<3,>=2 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.25.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.14->langchain-community) (0.3.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.14->langchain-community) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.125->langchain-community) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.125->langchain-community) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2024.8.30)
# Requirement already satisfied: anyio in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (1.0.6)
# Requirement already satisfied: sniffio in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.29->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.14->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.14->langchain-community) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Collecting langchain-openai
#   Downloading langchain_openai-0.3.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.29 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-openai) (0.3.29)
# Collecting openai<2.0.0,>=1.58.1 (from langchain-openai)
#   Downloading openai-1.59.7-py3-none-any.whl.metadata (27 kB)
# Collecting tiktoken<1,>=0.7 (from langchain-openai)
#   Downloading tiktoken-0.8.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: PyYAML>=5.3 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai) (0.2.6)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai) (9.0.0)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain-openai) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (0.6.1)
# Requirement already satisfied: sniffio in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (4.66.6)
# Requirement already satisfied: regex>=2022.1.18 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.58.1->langchain-openai) (3.10)
# Requirement already satisfied: certifi in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.29->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.29->langchain-openai) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.29->langchain-openai) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.29->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.29->langchain-openai) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/thiago/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.2.3)
# Downloading langchain_openai-0.3.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 kB 3.3 MB/s eta 0:00:00
# Downloading openai-1.59.7-py3-none-any.whl (454 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.8/454.8 kB 7.9 MB/s eta 0:00:00ta 0:00:01
# Downloading tiktoken-0.8.0-cp311-cp311-macosx_11_0_arm64.whl (982 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 982.4/982.4 kB 16.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: tiktoken, openai, langchain-openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.53.0
#     Uninstalling openai-1.53.0:
#       Successfully uninstalled openai-1.53.0
# Successfully installed langchain-openai-0.3.0 openai-1.59.7 tiktoken-0.8.0
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
from dotenv import load_dotenv

load_dotenv()

from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import CharacterTextSplitter

db = FAISS.from_documents(documents, OpenAIEmbeddings())

# %%
query = "Quando foi criado o projeto?"
docs = db.similarity_search(query)
docs
# Out:
# [Document(id='01f8dff1-76e6-4527-b4a0-e135ae2aa35b', metadata={'source': 'Projeto HidroNáutica X-700'}, page_content='## Projeto HidroNáutica X-700\n# Relatório Confidencial de Missão\n### Primeira Missão de Teste em Ambiente Extremo\n**Código da Missão:** NMEX-2038-001\n**Data da Missão:** 17 a 24 de março de 2038\n**Local:** Fossa das Marianas, Oceano Pacífico\n\n'),
#  Document(id='25fbfc26-1ca5-4743-a06b-534109e156af', metadata={'source': 'Projeto HidroNáutica X-700'}, page_content='## Projeto HidroNáutica X-700\n# Relatório Técnico Confidencial\n### Divisão de Robótica Submarina Avançada\n#### NeuroTech Oceanic Solutions\n**Versão do Documento: 1.4**\n**Data de Última Atualização: 15 de dezembro de 2037**\n\n'),
#  Document(id='4ae7e7d8-99d1-4277-9a23-6fc03de075a0', metadata={'source': '10. Equipe de Desenvolvimento'}, page_content='\n### 10.1 Liderança do Projeto\n\n#### Dra. Elena Rodrigues Silva\n**Cargo:** Diretora de Pesquisa e Coordenadora Geral do Projeto\n**Contribuições Principais:** \n- Concepção inicial do conceito biomimético\n- Definição da arquitetura geral do robô\n- Supervisão estratégica do desenvolvimento\n\n**Currículo Resumido:**\n- Doutorado em Robótica Biomimética pela Universidade de Stanford\n- Mais de 15 anos de experiência em desenvolvimento de robôs autônomos\n- Autora de 87 publicações científicas em robótica marinha\n- Membro da Academia Nacional de Engenharia desde 2033\n\n#### Dr. Marcus Chen Wong\n**Cargo:** Diretor Técnico de Engenharia\n**Contribuições Principais:**\n- Desenvolvimento do sistema de propulsão ondulante\n- Design dos atuadores piezoelétricos\n- Modelagem computacional dos sistemas de movimento\n\n**Currículo Resumido:**\n- PhD em Engenharia Biomecânica pelo MIT\n- Especialista mundial\n'),
#  Document(id='343e7b67-79fb-41bc-b72b-84ea7ff18c28', metadata={'source': '1. Introdução ao Projeto'}, page_content='## 1. Introdução ao Projeto\n\nO robô biomimético HidroNáutica X-700 representa um avanço revolucionário na exploração de ambientes submarinos extremos. Desenvolvido através de uma parceria interdisciplinar entre a NeuroTech Oceanic Solutions e o Instituto de Robótica Biomimética da Universidade Federal Marítima, o projeto visa criar um dispositivo de exploração que supere as limitações dos sistemas robóticos tradicionais.\n\n')]

# %% [markdown]
# ## Criando o RAG Agent
#
# Agora que temos o vector store populado, podemos criar o RAG Agent.

# %%
import getpass
import os

if not os.environ.get("OPENAI_API_KEY"):
  os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter API key for OpenAI: ")

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

llm = ChatOpenAI(model="gpt-4o-mini")
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")


def retrieve_docs(query: str) -> list[Document]:
    documents = db.similarity_search(query)
    context = "---\n".join([doc.page_content for doc in documents])
    return context

system_prompt = """
Você é um assitente, e seu objetivo é responder as perguntas do usuário, somente com base no contexto abaixo.
Não utilize seu conhecimento para responder as perguntas, somente utilize o contexto fornecido.
Se não souber a resposta, diga que não sabe. Não tente inventar uma resposta.
A seguir está o contexto disponível para que você extraia a resposta: 
<contexto>
{context}
</contexto>

Agora, responda a seguinte pergunta:
<pergunta>
{query}
</pergunta>
"""

prompt_template = ChatPromptTemplate.from_template(system_prompt)

def ask_rag(query: str) -> str:
    context = retrieve_docs(query)
    prompt = prompt_template.invoke({"query": query, "context": context})
    return llm.invoke(prompt).content
    

from pprint import pprint

# %%
print(ask_rag("onde foi a primeira expedição do projeto?"))
print("\n----\n")
print(ask_rag("quem criou o robô?"))
print("\n----\n")
print(ask_rag("quem foi da equipe do projeto?"))
print("\n----\n")
print(ask_rag("o robô tem alguma limitação?"))
# Out:
# A primeira expedição do projeto foi na Fossa das Marianas, no Oceano Pacífico.
#
# ----
#
# O robô biomimético HidroNáutica X-700 foi criado através de uma parceria interdisciplinar entre a NeuroTech Oceanic Solutions e o Instituto de Robótica Biomimética da Universidade Federal Marítima.
#
# ----
#
# A equipe do projeto foi composta por:
#
# 1. **Dra. Elena Rodrigues Silva** - Diretora de Pesquisa e Coordenadora Geral do Projeto.
# 2. **Dr. Marcus Chen Wong** - Diretor Técnico de Engenharia.
#
# ----
#
# Sim, o robô tem algumas limitações, como vulnerabilidade a campos eletromagnéticos intensos, tempo limitado de operação em zonas de temperatura extremamente baixa e dependência de calibração periódica dos sistemas neurais.
#
# ----
#
# O contexto não fornece informações específicas sobre o tempo de operação do robô. Portanto, não sei a resposta.

# %% [markdown]
# Agora, vamos fazer algumas perguntas que não estão no contexto dos documentos

# %%
print("\n----\n")
print(ask_rag("por quanto tempo o robô pode operar?"))
print("\n----\n")
print(ask_rag("quem ganhou a copa do mundo de 1998?"))
print("\n----\n")
print(ask_rag("qual a altura do monte Everest?"))
# Out:
# ----
#
# O contexto não fornece informações específicas sobre o tempo exato de operação do robô. Apenas menciona que ele tem um "tempo limitado de operação em zonas de temperatura extremamente baixa". Portanto, não sabe responder com precisão sobre o tempo de operação do robô.
#
# ----
#
# Não sei.
#
# ----
#
# Não sei.
